# %% [markdown]
# # Lab-7:
# ## Mini Project:
# ## Phase-1:
# #### Submit a python notebook with the preliminary analysis of data and record the objective of the project, data sources, data preparation steps etc. Identify the tech stack for the app.

# %% [markdown]
# > Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# > Loading Data Sets

# %%
links =  pd.read_csv('links.csv')
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
links.head(3)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0

# %%
movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
tags.head(3)
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %% [markdown]
# > Dropping 'timestamp' from 'tags.csv' and 'ratings.csv'

# %%
ratings.drop('timestamp', inplace=True, axis=1)
tags.drop('timestamp', inplace=True, axis=1)

# %% [markdown]
# > Merging the Data Sets

# %%
print("Links: {} rows.\nMovies: {} rows.\nRatings: {} rows.\nTags: {} rows.".format(links.shape[0],movies.shape[0],ratings.shape[0],tags.shape[0]))
# Out:
# Links: 9742 rows.
# Movies: 9742 rows.
# Ratings: 100836 rows.
# Tags: 3683 rows.

# %%
temp = pd.merge(links,movies)
temp.head(3)
# Out:
#    movieId  imdbId   tmdbId                    title  \
# 0        1  114709    862.0         Toy Story (1995)
# 1        2  113497   8844.0           Jumanji (1995)
# 2        3  113228  15602.0  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
data = pd.merge(temp, ratings)
data.shape
# Out:
# (100836, 7)

# %%
data.head(3)
# Out:
#    movieId  imdbId  tmdbId             title  \
# 0        1  114709   862.0  Toy Story (1995)
# 1        1  114709   862.0  Toy Story (1995)
# 2        1  114709   862.0  Toy Story (1995)
#
#                                         genres  userId  rating
# 0  Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1  Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# 2  Adventure|Animation|Children|Comedy|Fantasy       7     4.5

# %%
data.sort_values('userId', inplace=True, ascending=True)
data.head()
# Out:
#        movieId  imdbId   tmdbId                       title  \
# 0            1  114709    862.0            Toy Story (1995)
# 35548     1777  120888  11003.0  Wedding Singer, The (1998)
# 35249     1732  118715    115.0    Big Lebowski, The (1998)
# 34348     1676  120201    563.0    Starship Troopers (1997)
# 2379        50  114814    629.0  Usual Suspects, The (1995)
#
#                                             genres  userId  rating
# 0      Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 35548                               Comedy|Romance       1     4.0
# 35249                                 Comedy|Crime       1     5.0
# 34348                                Action|Sci-Fi       1     3.0
# 2379                        Crime|Mystery|Thriller       1     5.0

# %%
tags.head(3)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell

# %%
data = pd.merge(data, tags, how='outer')

# %%
data.head(3)
# Out:
#    movieId    imdbId   tmdbId                       title  \
# 0        1  114709.0    862.0            Toy Story (1995)
# 1     1777  120888.0  11003.0  Wedding Singer, The (1998)
# 2     1732  118715.0    115.0    Big Lebowski, The (1998)
#
#                                         genres  userId  rating  tag
# 0  Adventure|Animation|Children|Comedy|Fantasy       1     4.0  NaN
# 1                               Comedy|Romance       1     4.0  NaN
# 2                                 Comedy|Crime       1     5.0  NaN

# %% [markdown]
# > Extracting Genres from the Data set

# %%
genres = []
for i in data.genres:
    cnt = 0
    if cnt<5:
        print(i)
        cnt = cnt +1
# Out:
# Adventure|Animation|Children|Comedy|Fantasy
# Comedy|Romance
# Comedy|Crime
# Action|Sci-Fi
# Crime|Mystery|Thriller
# Horror|Mystery|Thriller
# Drama|Mystery|Thriller
# Comedy|Horror|Mystery|Thriller
# Comedy
# Crime|Drama|Mystery|Thriller
# Action|Adventure|Fantasy
# Action|Comedy|Sci-Fi
# Action|Crime|Drama|Thriller
# Action|Drama|War
# Action|Adventure|Thriller
# Action|Adventure|Thriller
# Action|Adventure|Comedy
# Crime|Film-Noir|Mystery|Thriller
# Crime|Drama
# Crime|Drama|Mystery|Thriller
# Action|Adventure|Sci-Fi|Thriller
# Adventure|Children|Comedy|Fantasy|Sci-Fi
# Action|Animation|Children|Crime
# Adventure|Children|Sci-Fi
# Adventure|Animation|Children|Fantasy
# Comedy|Romance
# Action|Drama|War
# Animation|Children|Drama
# Adventure|Animation|Children
# Adventure|Comedy|Sci-Fi|Western
# Action|Adventure|Children|Comedy|Fantasy
# Action|Comedy|Crime|Drama
# Comedy|Drama|War
# Adventure|Fantasy|Musical
# Drama
# Action|Drama|War
# Animation|Children|Fantasy|War
# ...
